# %%
# This is Main function.
# Extracting streaming data from Twitter, pre-processing, and loading into MySQL
import credentials # Import api/access_token keys from credentials.py
import settings # Import related setting constants from settings.py 

import re
import tweepy
import mysql.connector
import pandas as pd
from textblob import TextBlob
# Streaming With Tweepy 
# http://docs.tweepy.org/en/v3.4.0/streaming_how_to.html#streaming-with-tweepy


# Override tweepy.StreamListener to add logic to on_status

# %%
class MyStreamListener(tweepy.StreamListener):
    '''
    Tweets are known as “status updates”. So the Status class in tweepy has properties describing the tweet.
    https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object.html
    '''
    
    def on_status(self, status):
        '''
        Extract info from tweets
        '''
        
        if status.retweeted:
            # Avoid retweeted info, and only original tweets will be received
            return True
        # Extract attributes from each tweet
        id_str = status.id_str
        created_at = status.created_at
        text = deEmojify(status.text)    # Pre-processing the text  
        sentiment = TextBlob(text).sentiment
        polarity = sentiment.polarity
        subjectivity = sentiment.subjectivity
        
        user_created_at = status.user.created_at
        user_location = deEmojify(status.user.location)
        user_description = deEmojify(status.user.description)
        user_followers_count =status.user.followers_count
        longitude = None
        latitude = None
        if status.coordinates:
            longitude = status.coordinates['coordinates'][0]
            latitude = status.coordinates['coordinates'][1]
            
        retweet_count = status.retweet_count
        favorite_count = status.favorite_count
        
        print(status.text)
        print("Long: {}, Lati: {}".format(longitude, latitude))
        
        # Store all data in MySQL
        if mydb.is_connected():
            mycursor = mydb.cursor()
            sql = "INSERT INTO {} (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)".format(settings.TABLE_NAME)
            val = (id_str, created_at, text, polarity, subjectivity, user_created_at, user_location, \
                user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
            mycursor.execute(sql, val)
            mydb.commit()
            mycursor.close()
    
    
    def on_error(self, status_code):
        '''
        Since Twitter API has rate limits, stop srcraping data as it exceed to the thresold.
        '''
        if status_code == 420:
            # return False to disconnect the stream
            return False

# %%
def clean_tweet(self, tweet): 
    ''' 
    Use sumple regex statemnents to clean tweet text by removing links and special characters
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t]) \
                                |(\w+:\/\/\S+)", " ", tweet).split()) 
def deEmojify(text):
    '''
    Strip all non-ASCII characters to remove emoji characters
    '''
    if text:
        return text.encode('ascii', 'ignore').decode('ascii')
    else:
        return None

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitterdb",
    charset = 'utf8'
)
if mydb.is_connected():
    '''
    Check if this table exits. If not, then create a new one.
    '''
    mycursor = mydb.cursor()
    mycursor.execute("""
        SELECT COUNT(*)
        FROM information_schema.tables
        WHERE table_name = '{0}'
        """.format(settings.TABLE_NAME))
    if mycursor.fetchone()[0] != 1:
        mycursor.execute("CREATE TABLE {} ({})".format(settings.TABLE_NAME, settings.TABLE_ATTRIBUTES))
        mydb.commit()
    mycursor.close()

# %%
auth  = tweepy.OAuthHandler(credentials.API_KEY, credentials.API_SECRET_KEY)
auth.set_access_token(credentials.ACCESS_TOEKN, credentials.ACCESS_TOKEN_SECRET)
api = tweepy.API(auth)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
myStream.filter(languages=["en"], track = settings.TRACK_WORDS)

mydb.close()
# Out:
# RT @1YoungHustle_: 😂😂😂 Detroit a different breed dog look at what this Coronavirus shit done did to niggas https://t.co/Eho8czHAAQ
# Long: None, Lati: None
# RT @nayibbukele: Thank you @JackMa and @AlibabaGroup for your donation to our country.
#
# We received 100,000 masks; 10,080 testing kits for…
# Long: None, Lati: None
# RT @lizzkatherine_: BREAKING NEWS: Louisiana just released COVID-19 data which shows that African-Americans account for 70% of ALL DEATHS i…
# Long: None, Lati: None
# Coronavirus: News and live updates https://t.co/PwjHH7031I I am so happy with you, Yahoo..so smart , now we don't h… https://t.co/cTulSR9QW6
# Long: None, Lati: None
# RT @WHO: "We encourage countries that are considering the use of masks for the general population to study their effectiveness so we can al…
# Long: None, Lati: None
# RT @oldyfan2012: Trump "Has My Mom's Blood on His Hands": NYC Comptroller Stringer Accuses President in Coronavirus Death of His Elderly Mo…
# Long: None, Lati: None
# RT @NewsHour: "We governors have done far more than the president of the United States has to fight coronavirus...I'm upset with the federa…
# Long: None, Lati: None
# RT @RealCandaceO: Apparently, doctors and nurses around the world are wondering why no one is dying from heart attacks and strokes anymore.…
# Long: None, Lati: None
# tj is a terrorist orgn.hunt their men and shot https://t.co/bkDVLlgLKO arresting no https://t.co/IxMIfYro8z has end… https://t.co/7X2W4nkjMQ
# Long: None, Lati: None
# RT @brexit_sham: Spain is to roll out UBI “as soon as possible” to mitigate the impact of coronavirus. Their ambition is for UBI to become…
# Long: None, Lati: None
# RT @SenWarren: The Acting @SECNAV threw Captain Crozier under the bus without an investigation for trying to protect his crew from a corona…
# Long: None, Lati: None
# RT @MarkDice: CNN is the only network not airing President Trump's coronavirus press conference. https://t.co/KlD9clKV6B
# Long: None, Lati: None
# @DrSepinwall @csusm_chabss @schreiber_jason @ASI_CSUSM @DrSepinwall Thank you for sharing your student’s current ex… https://t.co/tevGDm32TQ
# Long: None, Lati: None
# RT @yaneerbaryam: BREAKING: Coronavirus Outbreak. Good news on multiple fronts
#
# US today now at 23,373, yesterday at this time was 30,571.…
# Long: None, Lati: None
# RT @Strandjunker: U.S. Navy SEAL Gallagher shot an unarmed man, shot a girl, stabbed an injured boy and posed with his dead body: pardoned…
# Long: None, Lati: None
# RT @HillaryWarnedUs: My mother died alone in the middle of the night calling out to God to release her from the pain. I was five hours away…
# Long: None, Lati: None
# RT @bennyjohnson: 20,000 RTs
# 5 million views.
# Annnnnnnnnd it's a lie.
# Long: None, Lati: None
# RT @Cartoon4sale: Morten Morland on the #Queen. #coronavirus #QueensSpeech #SocialDistancinguk #COVID19  #selfisolating #CoronavirusPandemi…
# Long: None, Lati: None
# RT @SethStein: We just rolled out a #COVID19 tool. See here for an interactive, real time map of essential and emergency construction work…
# Long: None, Lati: None
# RT @atDavidHoffman: 1/4 of all the coronavirus cases confirmed in the world are in the United States.
#
# That’s 25% of all cases. But we only…
# Long: None, Lati: None
# RT @zmughni: #indonesianenglishtweeting
# Why Japanese people are so calm in facing the covid19 pandemic, because 4 things 1. they are accus…
# Long: None, Lati: None
# RT @BBCWorld: Coronavirus: A visual guide to the world in lockdown https://t.co/EAKWCgZqLE
# Long: None, Lati: None
# RT @GordonGChang: How can #China's #coronavirus diagnostic kits, whether sold to the UK or elsewhere, be so inaccurate at this stage of the…
# Long: None, Lati: None
# Uncle Joe is not a nice man.
# Long: None, Lati: None
# RT @pmdfoster: NEW: SO. NHS is NOT just short of protective gear and ventilators, per fascinating leaked memo by senior doctor; also #COVID…
# Long: None, Lati: None
# Hundreds of homeless with coronavirus or symptoms housed at NYC hotels https://t.co/5iRdg002Py via @nypmetro
# Long: None, Lati: None
# RT @GmanFan45: OMG ARE DEMOCRATS WILLING TO LET PEOPLE DIE OR SUFFER? WHAT IS THEIR PROBLEM?! THIS IS  SICKNESS
# @POTUS
# @RudyGiuliani https…
# Long: None, Lati: None
# RT @RealMattCouch: BREAKING: A Potential Coronavirus Vaccine Funded by Bill Gates will begin testing on healthy people today in Kansas City…
# Long: None, Lati: None
# RT @JoeBiden: For months, I called on President Trump to step up and take the action necessary to combat COVID-19.
#
# But week after week, he…
# Long: None, Lati: None
# RT @JesseKellyDC: None of the people insisting you destroy your livelihood in the name of “the greater good” are in your shoes. They’re all…
# Long: None, Lati: None
# RT @BiggBossBites: We will win fight against CoronaVirus, no one is alone in this fight, we are together
# #StayHomeSavesLives
#
# Tweet... Twe…
# Long: None, Lati: None
# RT @MarkDice: CNN is the only network not airing President Trump's coronavirus press conference. https://t.co/KlD9clKV6B
# Long: None, Lati: None
# RT @jsolomonReports: News media, liberals mock conservatives for early pandemic comments they made themselves. A well researched story by S…
# Long: None, Lati: None
# RT @nandorvila: Ah yes... Elizabeth Warren and the CEO of the largest hedge fund in the world. A true "Team of Rivals" one might say.
# Long: None, Lati: None
# RT @LuisGuareguaM: Newsweek.- #Trump administration used Venezuela anti-drug operation to distract from coronavirus crisis at home, officia…
# Long: None, Lati: None
# RT @Catmandu50: BREAKING: Boris Johnson Moved to ICU as Coronavirus Condition “Has Worsened”
# Long: None, Lati: None
# #cubrebocas.        To help stop coronavirus, everyone should be wearing face masks. The science is clear | Coronav… https://t.co/G8fduRA831
# Long: None, Lati: None
# RT @AP: AP Investigation: The Trump administration squandered nearly two months that could have been used to bolster the federal stockpile…
# Long: None, Lati: None
# Trump says Democrats ‘shouldn’t be allowed to win’ 2020 election after his coronavirus response - https://t.co/b9vDQXnr9C
# Long: None, Lati: None
# RT @ANI: If a coronavirus positive person spits on any person, then, he/she will be charged with attempt to murder. If the person who has b…
# Long: None, Lati: None
# RT @PodSaveAmerica: "We knew what was happening in December...if we had started in January...we wouldn't be in quite such dire straits righ…
# Long: None, Lati: None
# RT @funder: Retweetfest: Tweet out the link below and we will retweet you! https://t.co/qDFaCyHrAo
# Long: None, Lati: None
# RT @DomenicoNPR: As the U.S. has passed 10,000 deaths from #coronavirus, all 50 states have cases and the only states with no deaths so far…
# Long: None, Lati: None
# RT @AdamW95: I took this picture, in the middle of my night shift as a make-shift ICU nurse, covered in sweat, sores on my face from my mas…
# Long: None, Lati: None
# RT @KatiePavlich: It was gracious for him to take your call as you desperately reach for relevancy from your house. Also, why was the stock…
# Long: None, Lati: None
# RT @ItoniLl: Dems conflicted over Biden's strategy during coronavirus – and angry at Bernie
#
# https://t.co/8c5mJIDPMR
# From the start every D…
# Long: None, Lati: None
# @juliaioffe “Every patient I've prescribed it to has been very, very ill and within 8 to 12 hours, they were basica… https://t.co/YTLGlotDIA
# Long: None, Lati: None
# Tennessee went from 4,000 to 500 today. And no mention of it anywhere.
# Long: None, Lati: None
# RT @Education4Libs: Twitter suspended me 12 hours followed by a WEEK for these tweets.
#
# They claimed I was “promoting or encouraging suicid…
# Long: None, Lati: None
# RT @FINCA: Crises exacerbate gender inequalities for women, girls, and other vulnerable populations. The global community's response to #CO…
# Long: None, Lati: None
# RT @Politidope: Trump got a "coronavirus determined to strike" warning and decided to tell people they'd get better by going to work.
# Long: None, Lati: None
# RT @Jali_Cat: ‼️Dr. Fauci MARCH 26, 2020:
#
# "[Coronavirus] is akin to a severe flu season. Mortality rates more likely in the 0.1% range".…
# Long: None, Lati: None
# RT @FrancisBrennan: “A Democratic state representative from Detroit is crediting hydroxychloroquine — and Republican President Donald Trump…
# Long: None, Lati: None
# @TIME CANADA CORRUPTION!JUST AS🇨🇳! TWIN COUNTRY!GOD BLESS AMERICA PLEASE USA WAKE UP! USA PLEASE SIGN THE PETITION… https://t.co/q6y3iRqb0N
# Long: None, Lati: None
# His cabinet of acting officials wonder too!
# #WorstPresidentInHistory
# Long: None, Lati: None
# Here's what we really learned in March 2020
#
# #KungFlu #CoronavirusUSA https://t.co/pddYqZUSZB
# Long: None, Lati: None
# Clearly this poll needs a truth injection.
# Long: None, Lati: None
# Fox News @KristinFisher got busted trying to get slick pretending not to know the IG was Obama's flunky..She a big… https://t.co/c4GnutDqaN
# Long: None, Lati: None
# RT @ossoff: NEW: U.S. Senator David Perdue (R-Ga.) bought stock in medical PPE producer DuPont de Nemours on Jan. 24, the same day the Sena…
# Long: None, Lati: None
# RT @Jeanna2007: OH. Look what this ole war monger just said. How do these people live sooooooo long?
# Long: None, Lati: None
# RT @UN_Women: Millions of women in the health and social sector work tirelessly every day to care for all of us.
# Ahead of #WorldHealthDay,…
# Long: None, Lati: None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-35e7576c969e> in <module>
#       1 myStreamListener = MyStreamListener()
#       2 myStream = tweepy.Stream(auth = api.auth, listener = myStreamListener)
# ----> 3 myStream.filter(languages=["en"], track = settings.TRACK_WORDS)
#       4
#       5 mydb.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     349             next_status_obj = buf.read_len(length)
#     350             if self.running and next_status_obj:
# --> 351                 self._data(next_status_obj)
#     352
#     353             # # Note: keep-alive newlines might be inserted before each length value.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _data(self, data)
#     321
#     322     def _data(self, data):
# --> 323         if self.listener.on_data(data) is False:
#     324             self.running = False
#     325
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in on_data(self, raw_data)
#      52         if 'in_reply_to_status_id' in data:
#      53             status = Status.parse(self.api, data)
# ---> 54             if self.on_status(status) is False:
#      55                 return False
#      56         elif 'delete' in data:
#
# <ipython-input-29-d3070c81a2a8> in on_status(self, status)
#      44                 user_description, user_followers_count, longitude, latitude, retweet_count, favorite_count)
#      45             mycursor.execute(sql, val)
# ---> 46             mydb.commit()
#      47             mycursor.close()
#      48
#
# KeyboardInterrupt:

# %%
mydb.close()

# %%
mydb
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-630c838f1343> in <module>
# ----> 1 mydb.show()
#
# AttributeError: 'CMySQLConnection' object has no attribute 'show'

# %%
db_connection = mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="password",
    database="twitterdb",
    charset = 'utf8'
)

# %%
db_connection

# %%
df = pd.read_sql('SELECT id_str, text, created_at, polarity, user_location FROM {}'.format(settings.TABLE_NAME), con=db_connection)

# %%
df
# Out:
#                   id_str                                               text  \
# 0    1247302110938529793  RT @RealCandaceO: Apparently, doctors and nurs...
# 1    1247302111093592065  RT @BiggBossBites: We clean oil spots on our c...
# 2    1247302110988972038                   Everything about this angers me.
# 3    1247302111274192896  RT @lizzkatherine_: BREAKING NEWS: Louisiana j...
# 4    1247302111215394816  RT @BlondieVex: So let me get this straight......
# ..                   ...                                                ...
# 829  1247309298155302918         Clearly this poll needs a truth injection.
# 830  1247309298230865921  Fox News @KristinFisher got busted trying to g...
# 831  1247309298323030018  RT @ossoff: NEW: U.S. Senator David Perdue (R-...
# 832  1247309298541244418  RT @Jeanna2007: OH. Look what this ole war mon...
# 833  1247309298582949888  RT @UN_Women: Millions of women in the health ...
#
#              created_at  polarity               user_location
# 0   2020-04-06 23:16:11         0                     Arizona
# 1   2020-04-06 23:16:11         0                          ca
# 2   2020-04-06 23:16:11         0                        None
# 3   2020-04-06 23:16:11         0  Orangeburg SC to Harlem NY
# 4   2020-04-06 23:16:11         0            Battle Creek, MI
# ..                  ...       ...                         ...
# 829 2020-04-06 23:44:45         0               MAGA COUNTRY
# 830 2020-04-06 23:44:45         0                        None
# 831 2020-04-06 23:44:45         0                         USA
# 832 2020-04-06 23:44:45         0               United States
# 833 2020-04-06 23:44:45         0                       India
#
# [834 rows x 5 columns]
